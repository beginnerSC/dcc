# %% [markdown]
# ```
# quant-solution/
# ├── src/
# │   └── quantlib/
# │       └── __init__.py
# │
# ├── cpp/
# │   ├── include/
# │   │   └── quant/
# │   │       ├── montecarlo/
# │   │       │   ├── mc_engine.hpp
# │   │       │   └── rng.hpp
# │   │       └── pde/
# │   │           ├── solver.hpp
# │   │           └── grid.hpp
# │   │
# │   ├── src/
# │   │   ├── montecarlo/
# │   │   │   ├── mc_engine.cpp
# │   │   │   └── rng.cpp
# │   │   └── pde/
# │   │       ├── solver.cpp
# │   │       └── grid.cpp
# │   │
# │   ├── bindings/
# │   │   ├── montecarlo_bindings.cpp
# │   │   └── pde_bindings.cpp
# │   │
# │   └── CMakeLists.txt
# │
# ├── tests/
# │   ├── cpp/
# │   │   ├── CMakeLists.txt
# │   │   ├── montecarlo/
# │   │   │   └── test_mc_engine.cpp
# │   │   └── pde/
# │   │       └── test_solver.cpp
# │   │
# │   └── python/
# │       └── test_quantlib.py
# │
# ├── docs/
# │   ├── conf.py
# │   ├── index.rst
# │   │
# │   ├── usage/                  # for users
# │   │   ├── api_reference.rst
# │   │   └── examples/
# │   │       └── basic_usage.ipynb
# │   │
# │   ├── dev_wiki/               # for developers
# │   │   ├── index.rst
# │   │   ├── montecarlo/
# │   │   │   ├── overview.ipynb
# │   │   │   └── design-tradeoffs.ipynb
# │   │   └── pde/
# │   │       ├── solver-structure.ipynb
# │   │       └── math-model.ipynb
# │   │
# │   └── notebooks/              # demo? is this subfolder necessary?
# │       ├── intro.ipynb
# │       └── pde_visualization.ipynb
# │
# ├── doxygen/
# │   ├── Doxyfile
# │   └── html/
# │
# ├── pyproject.toml
# ├── README.md
# └── .gitignore
# ```
