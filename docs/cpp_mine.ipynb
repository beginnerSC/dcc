# %% [markdown]
# # C++ Notes
#
# ## Overloading Operator `->`
#
# * The `->` operator has special compiler handling
# * Compiler translates `it->something` to `(it.operator->())->something` so operator should return a pointer
#
# ## List of Vector's Member Functions
#
# * Constructors
#     * `Vector()`
#     * `Vector(int)`
#     * Copy constructor
#     * Move constructor
# * Destructor
# * class iterator
#     * Constructor
#     * Destructor?
#     * operators `*`, `->`, `++`, `++(int)`, `==`, `!=`
# * begin
# * end
# * Print
# * PushBack
# * Resize
# * Size
# * Copy assignment
# * Move assignment
# * operator[]
